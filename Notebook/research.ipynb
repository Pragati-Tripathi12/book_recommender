# %%
print("ok")
# Out:
# ok

# %% [markdown]
# #### DATA LINK: https://www.kaggle.com/datasets/ra4u12/bookrecommendation

# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Program Files\KMSpico\temp\ipykernel_19336\2162656668.py in <module>
# ----> 1 import pandas as pd
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %%
books=pd.read_csv("BX-Books.csv",sep=";",encoding="latin-1",error_bad_lines=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Program Files\KMSpico\temp\ipykernel_19336\3271242326.py in <module>
# ----> 1 books=pd.read_csv("BX-Books.csv",sep=";",encoding="latin-1",error_bad_lines=False)
#
# NameError: name 'pd' is not defined
